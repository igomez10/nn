# %%
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
from helper import train_loop
from helper import fashionClassifierCNN
from helper import get_data
from helper import labels_map

device = (
    torch.accelerator.current_accelerator().type
    if torch.accelerator.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using mps device

# %%
training_data, test_data = get_data()

# split train dataset into train+validation
training_data, validation_data = torch.utils.data.random_split(training_data, [50000, 10000])

batch_size = 128
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
# Out:
# Downloading training data...
# Downloading test data...

# %%
model = fashionClassifierCNN(num_classes=10, in_channels=1).to(device)

optimizer = torch.optim.Adam(model.parameters())
train_loop(epochs=50, dataloader=train_dataloader, model=model, lossFn=nn.CrossEntropyLoss(), optimizer=optimizer, device=device)
# Out:
# epoch 0 loss 0.29869619011878974
# epoch 1 loss 0.26630330085754395
# epoch 2 loss 0.32431191205978394
# epoch 3 loss 0.2989349365234375
# epoch 4 loss 0.284576952457428
# epoch 5 loss 0.1813039630651474
# epoch 6 loss 0.17514371871948242
# epoch 7 loss 0.11893484741449356
# epoch 8 loss 0.11831537634134293
# epoch 9 loss 0.13036170601844788
# epoch 10 loss 0.080505497753620155
# epoch 11 loss 0.1700543463230133
# epoch 12 loss 0.20007891952991486
# epoch 13 loss 0.06821627914905548
# epoch 14 loss 0.047855719923973083
# epoch 15 loss 0.07983708381652832
# epoch 16 loss 0.12420646846294403
# epoch 17 loss 0.11254402250051498
# epoch 18 loss 0.016394564881920815
# epoch 19 loss 0.057928454130887985
# epoch 20 loss 0.0898887962102893625
# epoch 21 loss 0.07050617784261703
# epoch 22 loss 0.004292680881917477
# epoch 23 loss 0.059995926916599274
# epoch 24 loss 0.1729712039232254
# epoch 25 loss 0.029928332194685936
# epoch 26 loss 0.06429904699325562
# epoch 27 loss 0.003766872687265277
# epoch 28 loss 0.048527754843235016
# epoch 29 loss 0.025661062449216843
# epoch 30 loss 0.0407447926700115266
# epoch 31 loss 0.02069544419646263
# epoch 32 loss 0.04747847467660904
# epoch 33 loss 0.025424446910619736
# epoch 34 loss 0.038458067923784256
# epoch 35 loss 0.015057319775223732
# epoch 36 loss 0.008780780248343945
# epoch 37 loss 0.01528430450707674
# epoch 38 loss 0.003104113508015871
# epoch 39 loss 0.007111631333827972
# epoch 40 loss 0.02249257639050483763
# epoch 41 loss 0.04292668402194977
# epoch 42 loss 0.035244449973106384
# epoch 43 loss 0.004574914928525686
# epoch 44 loss 0.008890342898666859
# epoch 45 loss 0.0002884112764149904
# epoch 46 loss 0.055773667991161346
# epoch 47 loss 0.07653635740280151
# epoch 48 loss 1.9295661331852898e-05
# epoch 49 loss 0.04685860127210617

# %%
from helper import evaluateWithMax

evaluateWithMax(model, test_dataloader, device=device)
# Out:
# Got 8957 / 10000 with accuracy 0.90
