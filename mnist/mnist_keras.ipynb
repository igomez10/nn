# %%
import keras

# %% [markdown]
# # Load Data

# %%
# load mnist dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # Build Model

# %%
model = keras.Sequential(
    [
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(10, activation="softmax"),
    ]
)

optimizer = keras.optimizers.Adam()
loss = keras.losses.SparseCategoricalCrossentropy()
model_metric = keras.metrics.SparseCategoricalAccuracy()

# %% [markdown]
# # Train Model

# %%
model.compile(optimizer=optimizer, loss=loss, metrics=[model_metric])
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 591us/step - loss: 0.0333 - sparse_categorical_accuracy: 0.9876
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 584us/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9917
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 575us/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9931
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 578us/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9944
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 582us/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9956

# %% [markdown]
# # Evaluate Model

# %%
evres = model.evaluate(x_test, y_test)
print("Test Loss:", evres[0])
print("Test Accuracy:", evres[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9764
# Test Loss: 0.07529152184724808
# Test Accuracy: 0.9764000177383423
