# %% [markdown]
# - Loading data as pandas csv
# - preprocessing data
# - Creating dataloaders for data input
#   - dl_train = dl(train_df, batch_size=100, shuffle=True)
# - defining model architecture
#   - model = torch.nn.sequential
# - train the model
#   - optimizer = SGD(parameters=model.parameter, lr=0.001)
#   - loss_function = BCELoss()
#   - set number of epohs to train
#   - set train mode model.train()
#   - for i in epochs:
#     - for x, y in train_dl():
#       - optimizer.zerograd()
#       - predict = model(x)
#       - loss = lossFN(y, predict)
#       - model.backward()
#       - optimizer.step()
#   - evaluate the model
#     - model.eval()
#     - make predictions on validation data
#       - pred_val = model(x_val)
#       - loss = lossFn(prev_val, y_val)
#       - print
